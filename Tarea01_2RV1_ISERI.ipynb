# %% [markdown]
# **2.3 Ejercicios**
#
#
# *   Restaurante: a) Crear una clase llamada Restaurant. El método __init__() debe de aceptar dos atributos: El nombre_restaurant y el tipo_cocina.b) Crear un método que se llame describe_restaurant que imprima: El nombre del restaurant es: ------ y El tipo de comida que se sirve es: -------. c) Generar
# *  Tres Restaurantes: Crear tres restaurantes utilizando la clase que se ha definido con anterioridad y llame al método describe_restaurant para cada instancia de la clase.
#
#
# *   Usuarios: a) Cree una clase que se llame Usuario. b)Cree dos atributos llamados Nombre y Apellido, agregue atributos como CURP,Fecha_Nacimiento, Sexo, Grado_estudios. c)Genere un método llamado Saluda_usuario y que despliegue en pantalla algo como Hola Juan Ruiz de Alarcón. d)Genere un método que se llame Describe_usuario y que muestre toda la información del usuario. e)Genere 5 objetos tipo usuario y ejecute los dos métodos anteriormente descritos.
#
#
# **2.4.4 Ejercicios**
#
#
# *   Clientes atendidos: Retomar la clase de Restaurante que se generó a lo largo de este notebook y agregar un atributo que clientes_atendidos y agregar dos métodos: Clientes_Atendidos(self,numero): que pueda modificar el número de clientes 2.Aumenta_Clientes(self,numero): que pueda aumentar el número de clientes que se han atendido
# *   Control de acceso Acompletar el código de la siguiente celda, que crea una clase Usuario, donde el constructor debe de aceptar el nombre de usuario y la contraseña, cuando se invoque el método ingresar debe de pedir la contraseña del usuario, si la contraseña es correcta, debe de imprimir Bienvenido a su cuenta, si la contraseña se ingresa incorrectamente 3 veces debe de imprimir Cuenta bloquead, intente más tarde y debe de reiniciar la varialbe self.intentosAcceso a cero.
#
# **2.5.5 Ejercicio**
#
#
# *   Heladería: Una heladería se puede ver como un tipo específico de restaurante. Cree una clase que se llame Heladeria que herede de la clase Restaurante que se ha desarrollado en los ejercicios anteriores. Cree un atributo que se llame sabores que debe de ser una lista (estructura de datos). Agregar un método a la clase Heladeria que muestre los sabores que tiene.

# %%
class Restaurant():
  def __init__(self,nombre_restaurant,tipo_cocina):
    self.nombre_restaurant = nombre_restaurant
    self.tipo_cocina = tipo_cocina

  def describe_restaurant(self):
    describir = "el nombre del restaurante es:" + self.nombre_restaurant + "y el tipo de comida es:" + self.tipo_cocina

# %%
Primer_restaurante = Restaurant('HERVIL' , 'Cantonesa')
print("El nombre del restaurante es:" + Primer_restaurante.nombre_restaurant)
print("el tipo de comida es:" + Primer_restaurante.tipo_cocina)
# Out:
# El nombre del restaurante es:HERVIL
# el tipo de comida es:Cantonesa

# %%
Primer_restaurante = Restaurant('HERVIL' , 'Cantonesa')
Segundo_restaurante = Restaurant('Mar negro' , 'Marisqueria')
tercer_restaurante = Restaurant('Doña Yoli' , 'Corrida')

print("El nombre del restaurante es:" + Primer_restaurante.nombre_restaurant)
print("el tipo de comida es:" + Primer_restaurante.tipo_cocina)
print("\n")

print("El nombre del restaurante es:" + Segundo_restaurante.nombre_restaurant)
print("el tipo de comida es:" + Segundo_restaurante.tipo_cocina)
print("\n")

print("El nombre del restaurante es:" + tercer_restaurante.nombre_restaurant)
print("el tipo de comida es:" + tercer_restaurante.tipo_cocina)
# Out:
# El nombre del restaurante es:HERVIL
# el tipo de comida es:Cantonesa
#
#
# El nombre del restaurante es:Mar negro
# el tipo de comida es:Marisqueria
#
#
# El nombre del restaurante es:Doña Yoli
# el tipo de comida es:Corrida

# %%
class Usuario():
  def __init__(self,nombre,apellido,CURP,Fecha_de_Nacimiento,Sexo,Grado_de_estudios):
    self.nombre = nombre
    self.apellido = apellido
    self.CURP = CURP
    self.Fecha_de_Nacimiento = Fecha_de_Nacimiento 
    self.Sexo = Sexo
    self.Grado_de_estudios = Grado_de_estudios 

  def saludar_usuario(self):
    print("Hola" + self.nombre.title() + self.apellido)

  def describe_usuario(self):
    print("tu CURP es:" + self.CURP)
    print("tu fecha de nacimiento es:" + self.Fecha_de_Nacimiento)
    print("Tu genero es:" + self.Sexo)
    print("Tu nivel de estudios es:" + self.Grado_de_estudios)

# %%
 gesto_usuario = Usuario('Luz Jatziri', 'Hernández Villagómez', 'HEVL981211MDFRLZ07' , '11 de diciembre de 1998' , 'Femenino' , 'Ingenieria en proceso')

print("Hola " + gesto_usuario.nombre + " " + gesto_usuario.apellido)

gesto_usuario.describe_usuario()
# Out:
# Hola Luz Jatziri Hernández Villagómez
# tu CURP es:HEVL981211MDFRLZ07
# tu fecha de nacimiento es:11 de diciembre de 1998
# Tu genero es:Femenino
# Tu nivel de estudios es:Ingenieria en proceso

# %%
class Restaurant():
  def __init__(self,nombre_restaurant,tipo_cocina):
    self.nombre_restaurant = nombre_restaurant
    self.tipo_cocina = tipo_cocina
    self.numeros = numeros = 11

  def describe_restaurant(self):
    print("el nombre del restaurante es:" + self.nombre_restaurant + "y el tipo de comida es:" + self.tipo_cocina)

  def clientes_atendidos(self):
    print("el numero de clientes que se han atendido son: " + str(self.numeros))

  def aumento_clientes(self,numeros_suma):
    if numeros_suma >=0:
      print("Aumento de clientes")
      self.numeros += numeros_suma
    else:
      print("No existen mas clientes")

Primer_restaurante = Restaurant("HERVIL " , "Cantonesa")
Primer_restaurante.describe_restaurant()
Primer_restaurante.clientes_atendidos()
Primer_restaurante.aumento_clientes(7)
Primer_restaurante.clientes_atendidos()
# Out:
# el nombre del restaurante es:HERVIL y el tipo de comida es:Cantonesa
# el numero de clientes que se han atendido son: 11
# Aumento de clientes
# el numero de clientes que se han atendido son: 18

# %%
class Heladeria(Restaurant):
  def __init__(self,nombre,Cocina_Tipo):
    super().__init__(nombre,Cocina_Tipo)  
    self.sabores = ["Helado de Chicle","Helado de fresa","Helado de zarzamora", "Agua de frutas" , "Agua de Fresa", "Agua de piña-coco"]

  def mostrar_sabores(self):
    print("Los sabores disponibles son:")
    for i in self.sabores:
      print(i)

Postres = Heladeria("Frozen ", "Helados cremosos y bebidas frescas")
Postres.describe_restaurant()
Postres.mostrar_sabores()
# Out:
# el nombre del restaurante es:Frozen y el tipo de comida es:Helados cremosos y bebidas frescas
# Los sabores disponibles son:
# Helado de Chicle
# Helado de fresa
# Helado de zarzamora
# Agua de frutas
# Agua de Fresa
# Agua de piña-coco
